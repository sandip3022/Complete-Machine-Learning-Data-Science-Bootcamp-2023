# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
plt.plot()
# Out:
# []

# %%
plt.plot();

# %%
plt.plot()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.plot([1,2,3,4])

# %%
x =[1,2,3,4]

# %%
y = [11,22,33,44]

# %%
plt.plot(x,y)

# %%
# 1st Method
fig = plt.figure() # create a figure
ax = fig.add_subplot() # adds some axes
plt.show()

# %%
# 2nd method
fig =plt.figure()
ax = fig.add_axes([1,1,1,1])
ax.plot(x,y)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# 3rd method (recommended)
fig,ax = plt.subplots()
ax.plot(x,[20,90,200,440]);

# %% [markdown]
# ## Matplotlib Example Workflow

# %%
# 0. import matplotlib and get it ready for plot
# %matplotlib inline
import matplotlib.pyplot as plt

#1. Prepare data
x=[1,2,3,4]
y=[11,22,33,44]

#2. Setup data
fig,ax=plt.subplots(figsize=(5,5))

# 3. plot data
ax.plot(x,y)

#4. Customize plot
ax.set(title="Simple plot",
      xlabel="x-axis",
      ylabel=("y-axis"))

# 5. save & show 
fig.savefig("../sample.plot.png")

# %% [markdown]
# ## Making figure with Numpy
# we want
# * Line plot
# * Scatter plot
# * Bar Plot
# * Histogram
# *Subplots

# %%
import numpy as np

# %%
# create same data
x = np.linspace(1,10,100)
x
# Out:
# array([ 1.        ,  1.09090909,  1.18181818,  1.27272727,  1.36363636,
#         1.45454545,  1.54545455,  1.63636364,  1.72727273,  1.81818182,
#         1.90909091,  2.        ,  2.09090909,  2.18181818,  2.27272727,
#         2.36363636,  2.45454545,  2.54545455,  2.63636364,  2.72727273,
#         2.81818182,  2.90909091,  3.        ,  3.09090909,  3.18181818,
#         3.27272727,  3.36363636,  3.45454545,  3.54545455,  3.63636364,
#         3.72727273,  3.81818182,  3.90909091,  4.        ,  4.09090909,
#         4.18181818,  4.27272727,  4.36363636,  4.45454545,  4.54545455,
#         4.63636364,  4.72727273,  4.81818182,  4.90909091,  5.        ,
#         5.09090909,  5.18181818,  5.27272727,  5.36363636,  5.45454545,
#         5.54545455,  5.63636364,  5.72727273,  5.81818182,  5.90909091,
#         6.        ,  6.09090909,  6.18181818,  6.27272727,  6.36363636,
#         6.45454545,  6.54545455,  6.63636364,  6.72727273,  6.81818182,
#         6.90909091,  7.        ,  7.09090909,  7.18181818,  7.27272727,
#         7.36363636,  7.45454545,  7.54545455,  7.63636364,  7.72727273,
#         7.81818182,  7.90909091,  8.        ,  8.09090909,  8.18181818,
#         8.27272727,  8.36363636,  8.45454545,  8.54545455,  8.63636364,
#         8.72727273,  8.81818182,  8.90909091,  9.        ,  9.09090909,
#         9.18181818,  9.27272727,  9.36363636,  9.45454545,  9.54545455,
#         9.63636364,  9.72727273,  9.81818182,  9.90909091, 10.        ])

# %%
# Plot the data and 
fig,ax=plt.subplots()
ax.plot(x,x**2)

# %%
# Use some data to make scatter
fig,ax=plt.subplots()
ax.scatter(x,np.exp(x))

# %%
# Another scatter plot 
fig,ax = plt.subplots()
ax.scatter(x,np.sin(x))

# %%
# Make plot from Dictonary 
nut_butter_prices = {"Almond Butter": 10,
                    "Peanut Butter": 8,
                    "cashew Butter": 12}
fig,ax = plt.subplots()
ax.bar(nut_butter_prices.keys(),height=nut_butter_prices.values())
ax.set(title="Nut Butter store",
      ylabel="Prices ($)");

# %%
fig,ax =plt.subplots()
ax.barh(list(nut_butter_prices.keys()),list(nut_butter_prices.values()));

# %%
# make some data 
x= np.random.randn(1000)
fig,ax =plt.subplots()
ax.hist(x);

# %%
# subplot option
fig,((ax1,ax2),(ax3,ax4)) = plt.subplots(nrows=2,
                                        ncols=2,
                                        figsize=(10,  5))

# plot to each differnt axis
ax1.plot(x,x/2)
ax2.scatter(np.random.random(10),np.random.random(10))
ax3.barh(list(nut_butter_prices.keys()),list(nut_butter_prices.values()));
ax4.hist(np.random.random(1000));

# %%
# Subplot option 2
fig,ax = plt.subplots(nrows=2,
                     ncols=2,
                     figsize=(10,5))

#plot to each differnt index
ax[0,0].plot(x,x/2);
ax[0,1].scatter(np.random.random(10), np.random.random(10))
ax[1,0].barh(list(nut_butter_prices.keys()),list(nut_butter_prices.values()));
ax[1,1].hist(np.random.random(1000));

# %% [markdown]
# ## Plotting from pandas DataFrame

# %%
import pandas as pd
import numpy as np

# %%
# make a DataFrame
car_sales = pd.read_csv("car-sales.csv")
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
ts = pd.Series(np.random.randn(1000),
              index=pd.date_range("1/1/2020",periods=1000))
ts = ts.cumsum()
ts.plot()
# Out:
# <AxesSubplot:>

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales["Sale Date"] = pd.date_range("1/1/2020",periods=len(car_sales))
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Sale Date
# 0  Toyota  White         150043      4   $4,000.00 2020-01-01
# 1   Honda    Red          87899      4   $5,000.00 2020-01-02
# 2  Toyota   Blue          32549      3   $7,000.00 2020-01-03
# 3     BMW  Black          11179      5  $22,000.00 2020-01-04
# 4  Nissan  White         213095      4   $3,500.00 2020-01-05
# 5  Toyota  Green          99213      4   $4,500.00 2020-01-06
# 6   Honda   Blue          45698      4   $7,500.00 2020-01-07
# 7   Honda   Blue          54738      4   $7,000.00 2020-01-08
# 8  Toyota  White          60000      4   $6,250.00 2020-01-09
# 9  Nissan  White          31600      4   $9,700.00 2020-01-10

# %%
car_sales['Price'] = car_sales['Price'].str.replace('[\$,\,\.]', '', regex=True).astype(int)
car_sales.head()
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Sale Date
# 0  Toyota  White         150043      4   400000 2020-01-01
# 1   Honda    Red          87899      4   500000 2020-01-02
# 2  Toyota   Blue          32549      3   700000 2020-01-03
# 3     BMW  Black          11179      5  2200000 2020-01-04
# 4  Nissan  White         213095      4   350000 2020-01-05

# %%
# How about a bar graph 
x = np.random.rand(10,4)
x

# Turn it into dataframe
df = pd.DataFrame(x,columns = ['a','b','c','d'])
df
# Out:
#           a         b         c         d
# 0  0.837172  0.794383  0.521816  0.696663
# 1  0.535486  0.840586  0.719479  0.310705
# 2  0.303386  0.058423  0.663414  0.223436
# 3  0.094782  0.996229  0.610438  0.581627
# 4  0.864556  0.918396  0.752150  0.726561
# 5  0.574091  0.136023  0.467712  0.251544
# 6  0.897949  0.870646  0.134100  0.331674
# 7  0.379919  0.269033  0.849111  0.898145
# 8  0.640527  0.365936  0.667438  0.054329
# 9  0.638891  0.858794  0.654885  0.246371

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
# method 1
df.plot.bar()
# Out:
# <AxesSubplot:>

# %%
# method 2
df.plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
car_sales.plot(x="Make",y="Odometer (KM)",kind="bar");

# %%
# how to do histogram
car_sales["Odometer (KM)"].plot.hist();

# %%
car_sales["Odometer (KM)"].plot.hist();

# %%
car_sales["Odometer (KM)"].plot.hist(bins=10);

# %%
# Lets try on another dataset
heart_disease = pd.read_csv("heart-disease.csv")
heart_disease.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
# create a histogram of age
heart_disease["age"].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
heart_disease.plot.hist(subplots=True);

# %%
heart_disease.plot.hist(figsize = (5,30),subplots=True);

# %% [markdown]
# # Which one should you use pyploy or matplot?
#
# * when plotting something quickly use pyplot
# * when plotting more advanced use matplot

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
heart_disease = pd.read_csv("heart-disease.csv")
heart_disease
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# 2        2   0     2       1
# 3        2   0     2       1
# 4        2   0     2       1
# ..     ...  ..   ...     ...
# 298      1   0     3       0
# 299      1   0     3       0
# 300      1   2     3       0
# 301      1   1     3       0
# 302      1   1     2       0
#
# [303 rows x 14 columns]

# %%
over_50 = heart_disease[heart_disease["age"]>50]
over_50.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
# 5   57    1   0       140   192    0        1      148      0      0.4      1
# 6   56    0   1       140   294    0        0      153      0      1.3      1
#
#    ca  thal  target
# 0   0     1       1
# 3   0     2       1
# 4   0     2       1
# 5   0     1       1
# 6   0     2       1

# %%
over_50.plot(kind='scatter',
            x='age',
            y = 'chol',
            c='target');

# %%
#oo method
fix, ax = plt.subplots(figsize=(10, 6))
over_50.plot(kind='scatter',
            x='age',
            y= 'chol',
            c='target',
            ax=ax)
# Out:
# <AxesSubplot:xlabel='age', ylabel='chol'>

# %%
# oo method from scratch
fig, ax= plt.subplots(figsize=(10,6))

# plot the data
scatter = ax.scatter(x=over_50["age"],
                    y=over_50["chol"],
                    c=over_50["target"]);

#customize the plot
ax.set(title="Heart Disease and cholesterol Levels ",
      xlabel="Age",
      ylabel="Cholesterol");

# add a legend
ax.legend(*scatter.legend_elements(), title="Target");

# add a horizontal line
ax.axhline(over_50["chol"].mean(),
          linestyle="--");

# %%
over_50.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
# 5   57    1   0       140   192    0        1      148      0      0.4      1
# 6   56    0   1       140   294    0        0      153      0      1.3      1
#
#    ca  thal  target
# 0   0     1       1
# 3   0     2       1
# 4   0     2       1
# 5   0     1       1
# 6   0     2       1

# %%
# Subplot of chol, age, thalach
fig,(ax0, ax1) = plt.subplots(nrows = 2,
                             ncols = 1,
                             figsize=(10,10),
                             sharex=True)

# Add data
scatter =ax0.scatter(x=over_50["age"],
                     y = over_50["chol"],
                    c=over_50["target"])

# customize ax0
ax0.set(title="Heart Disese and Cholestrol levels",
       ylabel="Cholestrol")

# add legend to ax0
ax0.legend(*scatter.legend_elements(), title="Target")

# Add a legend meanline
ax0.axhline(y=over_50["chol"].mean(),
            linestyle="--");


# Add data to ax1
scatter =ax1.scatter(x=over_50["age"],
                    y=over_50["thalach"],
                    c=over_50["target"])

# Customise ax1
ax1.set(title="Heart Disease and max Heart Rate",
       xlabel="Age",
       ylabel="Max Heart rate");

#Add a legend 
ax1.legend(*scatter.legend_elements(),title="target")

# Add a meanline
ax1.axhline(y=over_50["thalach"].mean(),
           linestyle="--");


# add title to figure
fig.suptitle("Heart disease Analysis")
# Out:
# Text(0.5, 0.98, 'Heart disease Analysis')

# %% [markdown]
# ## Customizing Matplotlib Plot and getting stylish

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
plt.style.use('seaborn-whitegrid')

# %%
heart_disease["age"].plot();

# %%
plt.style.use('seaborn')
heart_disease["thalach"].plot();

# %%
heart_disease.plot(x="age",y="thalach",kind="scatter")
# Out:
# <AxesSubplot:xlabel='age', ylabel='thalach'>

# %%
plt.style.use('ggplot')
heart_disease["thalach"].plot();

# %%
# create some data
x = np.random.randn(10,4)
x
# Out:
# array([[-0.17646032, -0.0153437 ,  1.12741064,  1.19427343],
#        [-0.16031756, -0.3595889 , -0.78513974, -1.31511073],
#        [-0.67519848, -1.0092267 , -0.42956218, -0.08176834],
#        [ 0.56143982,  1.59901257,  0.50573518,  0.06179027],
#        [-0.65437762, -0.46531863, -0.76082954,  0.82632118],
#        [ 0.30672038,  1.17498042,  0.50034718,  1.01566389],
#        [-1.06288698,  2.22543343,  0.43669842,  1.50769063],
#        [ 0.55909208, -0.11392104, -1.4632677 , -1.06766442],
#        [-0.02775055, -1.51961362, -1.06100541, -2.91299725],
#        [-2.54189046,  1.21033011,  1.96059006, -0.47153183]])

# %%
df = pd.DataFrame(x,columns=['a','b','c','d'])
df
# Out:
#           a         b         c         d
# 0 -0.176460 -0.015344  1.127411  1.194273
# 1 -0.160318 -0.359589 -0.785140 -1.315111
# 2 -0.675198 -1.009227 -0.429562 -0.081768
# 3  0.561440  1.599013  0.505735  0.061790
# 4 -0.654378 -0.465319 -0.760830  0.826321
# 5  0.306720  1.174980  0.500347  1.015664
# 6 -1.062887  2.225433  0.436698  1.507691
# 7  0.559092 -0.113921 -1.463268 -1.067664
# 8 -0.027751 -1.519614 -1.061005 -2.912997
# 9 -2.541890  1.210330  1.960590 -0.471532

# %%
ax = df.plot(kind='bar')

# %%
# Customize our plot with the set () method
ax = df.plot(kind="bar")

# Add some title and label
ax.set(title="Random Number Bar Graph from dataframe",
      xlabel="Row Number",
      ylabel=" Random NUmber")

# Make the legend visile
ax.legend().set_visible(True)

# %%
# set style
plt.style.use('seaborn-whitegrid')

# oo method from scratch
fig, ax= plt.subplots(figsize=(10,6))

# plot the data
scatter = ax.scatter(x=over_50["age"],
                    y=over_50["chol"],
                    c=over_50["target"],
                    cmap="winter"); # color scheme

#customize the plot
ax.set(title="Heart Disease and cholesterol Levels ",
      xlabel="Age",
      ylabel="Cholesterol");

# add a legend
ax.legend(*scatter.legend_elements(), title="Target");

# add a horizontal line
ax.axhline(over_50["chol"].mean(),
          linestyle="--");

# %%
# set style
plt.style.use('seaborn-colorblind')

# oo method from scratch
fig, ax= plt.subplots(figsize=(10,6))

# plot the data
scatter = ax.scatter(x=over_50["age"],
                    y=over_50["chol"],
                    c=over_50["target"],
                    cmap="plasma");

#customize the plot
ax.set(title="Heart Disease and cholesterol Levels ",
      xlabel="Age",
      ylabel="Cholesterol");

# add a legend
ax.legend(*scatter.legend_elements(), title="Target");

# add a horizontal line
ax.axhline(over_50["chol"].mean(),
          linestyle="--");

# %%
# custmize y and x axis limit

# Subplot of chol, age, thalach
fig,(ax0, ax1) = plt.subplots(nrows = 2,
                             ncols = 1,
                             figsize=(10,10),
                             sharex=True)

# Add data
scatter =ax0.scatter(x=over_50["age"],
                     y = over_50["chol"],
                    c=over_50["target"],
                    cmap="summer")

# customize ax0
ax0.set(title="Heart Disese and Cholestrol levels",
       ylabel="Cholestrol")
ax0.set_xlim([50,80])
# add legend to ax0
ax0.legend(*scatter.legend_elements(), title="Target")

# Add a legend meanline
ax0.axhline(y=over_50["chol"].mean(),
            linestyle="--");


# Add data to ax1
scatter =ax1.scatter(x=over_50["age"],
                    y=over_50["thalach"],
                    c=over_50["target"],
                    cmap="winter")
# change x axix limit
ax0.set_xlim([50,80])
# Customise ax1
ax1.set(title="Heart Disease and max Heart Rate",
       xlabel="Age",
       ylabel="Max Heart rate");

#Add a legend 
ax1.legend(*scatter.legend_elements(),title="target")

# Add a meanline
ax1.axhline(y=over_50["thalach"].mean(),
           linestyle="--");


# add title to figure
fig.suptitle("Heart disease Analysis",
            fontsize=("30"))
# Out:
# Text(0.5, 0.98, 'Heart disease Analysis')

# %% [markdown]
# ## saving figure

# %%
fig.savefig("heart disease analysis plot")
